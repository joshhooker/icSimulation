# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
roundData = pd.read_csv('round4/output_raw.log', sep=" ", header=None)
roundData = roundData.rename(columns={0: 'Gas Type', 1: 'Pressure', 2: 'Number of Grids',
                                        3: 'Center Grid Distance', 4: 'Scintillator Distance',
                                        5: 'Silhouette', 6: 'Efficiency'})

# %%
roundData['Score'] = roundData['Silhouette']*2 + roundData['Efficiency']

# %%
roundData.head()
# Out:
#    Gas Type   Pressure  Number of Grids  Center Grid Distance  \
# 0         2  87.825603                3             94.442479
# 1         1  88.144952                4             49.647046
# 2         1  37.604084                4             93.521290
# 3         1  66.152852                3             74.763604
# 4         2  57.627040                2             45.108895
#
#    Scintillator Distance  Silhouette  Efficiency     Score
# 0             138.722237    0.372607    0.745657  1.490871
# 1             204.968709    0.371107    0.719930  1.462145
# 2             141.818996    0.279294    0.941825  1.500412
# 3             154.947497    0.310861    0.859599  1.481322
# 4             174.728398    0.359863    0.765726  1.485452

# %%
roundData.plot(y = 'Score')

# %%
roundData = roundData.sort_values(by=['Score'], ascending=False)
top15 = roundData.head(15)

# %%
top15.hist('Gas Type', bins=3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1092ade10>]],
#       dtype=object)

# %%
top15.plot.scatter(x='Gas Type', y='Efficiency')

# %%
top15.plot.scatter(x='Gas Type', y='Silhouette')

# %%
round4Data.plot.scatter(x='Efficiency', y='Silhouette')

# %%
topEfficiency = roundData[roundData['Efficiency'] > 0.6]

# %%
topEfficiency = topEfficiency.sort_values(by=['Score'], ascending=False)
top15 = topEfficiency.head(15)

# %%
top15.hist('Gas Type', bins=3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1092a1630>]],
#       dtype=object)

# %%
top15.plot.scatter(x='Gas Type', y='Efficiency')

# %%
top15.plot.scatter(x='Gas Type', y='Silhouette')

# %%
top15.plot.scatter(figsize=(12,8),
                   x='Efficiency',
                   y='Silhouette',
                   s=100,
                   #c='Gas Type',
                   #colormap='RdYlBu_r'
                  )
